# %%
import openpyxl
import pandas as pd

wb = openpyxl.load_workbook("50data_0_1.xlsx")
sh = wb['sheet1']
data = pd.read_excel('50data_0_1.xlsx')

print(sh.cell(1,2).value)
no_col = sh.max_column
no_col

count_0 = 0
count_1 = 0
count_2 = 0
count_3 = 0
count_4 = 0
count_5 = 0
count_6 = 0
for i in range(2, sh.max_row+1):
    for j in range(1,no_col+1):
        for k in range(j+1,no_col+1): 
            if sh.cell(i,j).value == 1  and sh.cell(i,k).value == 1:
                print("{", sh.cell(1,j).value, ",", sh.cell(1,k).value ,"} " , end = " ")
                hashfun = (j * 10 + k)%7
                #print(hashfun)
                if hashfun == 0:
                    count_0 = count_0 + 1
                elif hashfun == 1:
                    count_1 = count_1 + 1
                elif hashfun == 2:
                    count_2 = count_2 + 1
                elif hashfun == 3:
                    count_3 = count_3 + 1
                elif hashfun == 4:
                    count_4 = count_4 + 1
                elif hashfun == 5:
                    count_5 = count_5 + 1
                elif hashfun == 6:
                    count_6 = count_6 + 1
                    
    print()
                        
                        
print(count_0, end = " ")
print(count_1, end = " ")
print(count_2, end = " ")
print(count_3, end = " ")
print(count_4, end = " ")
print(count_5, end = " ")
print(count_6)

supp = (count_0+count_1+count_2+count_3+count_4+count_5+count_6)/7
if count_0 >= supp:
    print(1, end = " ")
else:
    print(0, end = " ")
    
if count_1 >= supp:
    print(1, end = " ")
else:
    print(0, end = " ")
    
if count_2 >= supp:
    print(1, end = " ")
else:
    print(0, end = " ")
    

    
if count_3 >= supp:
    print(1, end = " ")
else:
    print(0, end = " ")
    
if count_4 >= supp:
    print(1, end = " ")
else:
    print(0, end = " ")
    
if count_5 >= supp:
    print(1, end = " ")
else:
    print(0, end = " ")
print("done")
# Out:
#  brownies
# ...
